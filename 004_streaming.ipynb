# %%
# Run using ms-toolsai.jupyter for VSCode

# %%
# Install dependencies
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in c:\Users\DanielBencz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (0.116.0)
# Requirement already satisfied: python-dotenv in c:\Users\DanielBencz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\Users\DanielBencz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (4.14.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\Users\DanielBencz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in c:\Users\DanielBencz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\Users\DanielBencz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\Users\DanielBencz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (0.16.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\Users\DanielBencz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: sniffio in c:\Users\DanielBencz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in C:\Users\DanielBencz\AppData\Roaming\Python\Python314\site-packages (from anthropic) (4.16.0)
# Requirement already satisfied: idna>=2.8 in c:\Users\DanielBencz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anyio<5,>=3.5.0->anthropic) (3.18)
# Requirement already satisfied: certifi in c:\Users\DanielBencz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.25.0->anthropic) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\Users\DanielBencz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\Users\DanielBencz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\DanielBencz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\DanielBencz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\DanielBencz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
#  Load env vars
from dotenv import load_dotenv
# import os

load_dotenv()
# print(os.environ['ANTHROPIC_API_KEY'])
# Out:
# True

# %%
# Create API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-5"

# %%
# Helper functions to preserve history
def add_user_message(messages, text):
  user_message = {"role": "user", "content": text}
  messages.append(user_message)

def add_assistant_message(messages, text):
  assistant_message = {"role": "assistant", "content": text}
  messages.append(assistant_message)

# %%
messages = []
add_user_message(messages, "Write a 1 sentence description of a fake database")

# %%
# Manual method to iterate over the events
stream = client.messages.create(
  model=model,
  max_tokens=1000,
  messages=messages,
  stream=True # <--
)

for event in stream:
  print(event)

# %%
# Using the Streaming Interface
with client.messages.stream(
  model=model,
  max_tokens=1000,
  messages=messages
) as stream:
    for text in stream.text_stream:
      print(text, end="")

# Get the complete message for database storage
final_message = stream.get_final_message()
# Out:
# A cloud-based NoSQL database called "Cloudary" that stores customer data in flexible, schema-less documents and automatically scales across distributed servers to handle millions of real-time queries per second.

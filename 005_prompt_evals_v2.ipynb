# %%
# Run using ms-toolsai.jupyter for VSCode

# %%
# Install dependencies
# %pip install anthropic python-dotenv

# %%
#  Load env vars
from dotenv import load_dotenv
# import os

load_dotenv()
# print(os.environ['ANTHROPIC_API_KEY'])

# %%
# Create API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions to preserve history
def add_user_message(messages, text):
  user_message = {"role": "user", "content": text}
  messages.append(user_message)

def add_assistant_message(messages, text):
  assistant_message = {"role": "assistant", "content": text}
  messages.append(assistant_message)

def chat(messages, system=None, temperature=0.5, stop_sequences=[]):
  params = {
    "model": model,
    "max_tokens": 1000,
    "messages": messages,
    "temperature": temperature,
    "stop_sequences": stop_sequences,
  }
  
  if system:
    params["system"] = system
  
  message = client.messages.create(**params)
  return message.content[0].text

# %%
import json

def generate_dataset():
  """"Generates a dataset for a prompt evaluation"""

  prompt = """
Generate an evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects, each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
  {
    "task": "Description of task",
  },
  ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a single regex
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

  messages = []
  add_user_message(messages, prompt)
  add_assistant_message(messages, "```json")
  text = chat(messages, stop_sequences=["```"])
  return json.loads(text)

# %%
dataset = generate_dataset()

with open('dataset.json', 'w') as f:
  json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""
    
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    
    output = run_prompt(test_case)
    
    # TODO - Grading
    score = 10
    
    return {
        "output": output,
        "test_case": test_case,
        "score": score
    }

# %%
def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    
    results = []
    
    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)
    
    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Name Validator\n\nHere's a Python function that validates AWS S3 bucket names according to the naming conventions:\n\n```python\nimport re\n\ndef is_valid_s3_bucket_name(bucket_name):\n    \"\"\"\n    Validates if a bucket name follows AWS S3 naming conventions.\n    \n    AWS S3 bucket naming rules:\n    - Must be between 3 and 63 characters long\n    - Must start and end with a lowercase letter or number\n    - Can only contain lowercase letters, numbers, and hyphens (-)\n    - Cannot contain underscores\n    - Cannot be formatted as an IP address (e.g., 192.168.1.1)\n    \n    Args:\n        bucket_name (str): The S3 bucket name to validate\n        \n    Returns:\n        bool: True if valid, False otherwise\n    \"\"\"\n    \n    # Check if bucket_name is a string\n    if not isinstance(bucket_name, str):\n        return False\n    \n    # Check length (3-63 characters)\n    if len(bucket_name) < 3 or len(bucket_name) > 63:\n        return False\n    \n    # Check for underscores (not allowed)\n    if '_' in bucket_name:\n        return False\n    \n    # Check for uppercase letters (must be lowercase)\n    if bucket_name != bucket_name.lower():\n        return False\n    \n    # Check if starts and ends with lowercase letter or number\n    if not (bucket_name[0].isalnum() and bucket_name[-1].isalnum()):\n        return False\n    \n    # Check if contains only lowercase letters, numbers, and hyphens\n    if not re.match(r'^[a-z0-9][a-z0-9\\-]*[a-z0-9]$|^[a-z0-9]$', bucket_name):\n        return False\n    \n    # Check if it's formatted as an IP address (not allowed)\n    if re.match(r'^(\\d+\\.){3}\\d+$', bucket_name):\n        return False\n    \n    return True\n```\n\n## Usage Examples\n\n```python\n# Valid bucket names\nprint(is_valid_s3_bucket_name(\"my-bucket\"))              # True\nprint(is_valid_s3_bucket_name(\"my-bucket-123\"))          # True\nprint(is_valid_s3_bucket_name(\"abc\"))                    # True\nprint(is_valid_s3_bucket_name(\"a1b2c3\"))                 # True\n\n# Invalid bucket names\nprint(is_valid_s3_bucket_name(\"My-Bucket\"))              # False (uppercase)\nprint(is_valid_s3_bucket_name(\"my_bucket\"))              # False (underscore)\nprint(is_valid_s3_bucket_name(\"my-bucket-\"))             # False (ends with hyphen)\nprint(is_valid_s3_bucket_name(\"-my-bucket\"))             # False (starts with hyphen)\nprint(is_valid_s3_bucket_name(\"ab\"))                     # False (too short)\nprint(is_valid_s3_bucket_name(\"a\" * 64))                 # False (too long)\nprint(is_valid_s3_bucket_name(\"192.168.1.1\"))            # False (IP address format)\nprint(is_valid_s3_bucket_name(\"my bucket\"))              # False (contains space)\nprint(is_valid_s3_bucket_name(\"\"))                       # False (empty)\nprint(is_valid_s3_bucket_name(123))                      # False (not a string)\n```\n\n## Simplified Version\n\nIf you prefer a more concise version:\n\n```python\nimport re\n\ndef is_valid_s3_bucket_name(bucket_name):\n    \"\"\"Validates AWS S3 bucket naming conventions.\"\"\"\n    if not isinstance(bucket_name, str):\n        return False\n    \n    # Pattern: 3-63 chars, lowercase letters/numbers/hyphens, \n    # starts and ends with alphanumeric, not an IP address\n    pattern = r'^[a-z0-9]([a-z0-9",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS S3 bucket name and returns True if it follows AWS naming conventions (lowercase, 3-63 characters, no underscores), False otherwise."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS IAM Read-Only S3 Bucket Policy\n\nHere's a JSON object that represents an AWS IAM policy for read-only access to a specific S3 bucket:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"ListBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketLocation\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket\"\n    },\n    {\n      \"Sid\": \"GetObjectReadOnly\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket/*\"\n    }\n  ]\n}\n```\n\n## Explanation of Permissions:\n\n| Permission | Purpose |\n|-----------|---------|\n| **s3:ListBucket** | Allows listing the contents of the bucket |\n| **s3:GetBucketLocation** | Allows retrieving the bucket's region |\n| **s3:GetObject** | Allows reading/downloading objects from the bucket |\n| **s3:GetObjectVersion** | Allows reading specific versions of objects |\n\n## Key Points:\n\n- \u2705 **Read-only**: No write, delete, or modify permissions included\n- \u2705 **Bucket-specific**: Only applies to `my-data-bucket`\n- \u2705 **Standard format**: Uses AWS IAM policy structure (Version 2012-10-17)\n- \u2705 **Organized**: Separated into logical statement groups\n\nYou can attach this policy to an IAM user, role, or group to grant read-only access to the specified bucket.",
#     "test_case": {
#       "task": "Create a JSON object that represents an AWS IAM policy allowing read-only access to a specific S3 bucket named 'my-data-bucket'."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS EC2 Instance ID Regex Pattern\n\nHere's the regex pattern that matches valid AWS EC2 instance IDs:\n\n```regex\n^i-[0-9a-f]{17}$\n```\n\n## Explanation\n\n| Component | Description |\n|-----------|-------------|\n| `^` | Start of string anchor |\n| `i-` | Literal \"i-\" prefix (required for EC2 instance IDs) |\n| `[0-9a-f]` | Character class matching hexadecimal digits (0-9, a-f) |\n| `{17}` | Exactly 17 hexadecimal characters |\n| `$` | End of string anchor |\n\n## Examples\n\n### Valid matches:\n```\ni-0a1b2c3d4e5f6g7h8\ni-1234567890abcdef0\ni-ffffffffffffffff0\n```\n\n### Invalid matches:\n```\ni-0a1b2c3d4e5f6g7h      (only 16 chars)\ni-0a1b2c3d4e5f6g7h8i    (18 chars)\n0a1b2c3d4e5f6g7h8       (missing i- prefix)\ni-0a1b2c3d4e5f6g7hZ     (contains non-hex character Z)\n```\n\n## Usage Examples\n\n### JavaScript\n```javascript\nconst pattern = /^i-[0-9a-f]{17}$/;\nconsole.log(pattern.test('i-1234567890abcdef0')); // true\nconsole.log(pattern.test('i-invalid')); // false\n```\n\n### Python\n```python\nimport re\npattern = r'^i-[0-9a-f]{17}$'\nprint(re.match(pattern, 'i-1234567890abcdef0'))  # Match object\nprint(re.match(pattern, 'i-invalid'))  # None\n```",
#     "test_case": {
#       "task": "Write a regex pattern that matches valid AWS EC2 instance IDs (format: i- followed by 17 hexadecimal characters)."
#     },
#     "score": 10
#   }
# ]

# %%
# Run using ms-toolsai.jupyter for VSCode

# %%
# Install dependencies
# %pip install anthropic python-dotenv

# %%
#  Load env vars
from dotenv import load_dotenv
# import os

load_dotenv()
# print(os.environ['ANTHROPIC_API_KEY'])

# %%
# Create API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions to preserve history
def add_user_message(messages, text):
  user_message = {"role": "user", "content": text}
  messages.append(user_message)

def add_assistant_message(messages, text):
  assistant_message = {"role": "assistant", "content": text}
  messages.append(assistant_message)

def chat(messages, system=None, temperature=0.5, stop_sequences=[]):
  params = {
    "model": model,
    "max_tokens": 1000,
    "messages": messages,
    "temperature": temperature,
    "stop_sequences": stop_sequences,
  }
  
  if system:
    params["system"] = system
  
  message = client.messages.create(**params)
  return message.content[0].text

# %%
import json

def generate_dataset():
  """"Generates a dataset for a prompt evaluation"""

  prompt = """
Generate an evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects, each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
  {
    "task": "Description of task",
  },
  ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a single regex
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

  messages = []
  add_user_message(messages, prompt)
  add_assistant_message(messages, "```json")
  text = chat(messages, stop_sequences=["```"])
  return json.loads(text)

# %%
dataset = generate_dataset()

with open('dataset.json', 'w') as f:
  json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""
    
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
  eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
  "strengths": string[],
  "weaknesses": string[],
  "reasoning": string,
  "score": number
}}
"""

  messages = []
  add_user_message(messages, eval_prompt)
  add_assistant_message(messages, "```json")
  eval_text = chat(messages, stop_sequences=["```"])
  return json.loads(eval_text)

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    
    output = run_prompt(test_case)
    model_grade = grade_by_model(test_case, output)
    
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]
    
    return {
        "test_case": test_case,
        "output": output,
        "score": score,
        "reasoning": reasoning
    }

# %%
from statistics import mean

def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    
    results = []
    
    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)
    
    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Name Validator\n\n```python\ndef is_valid_s3_bucket_name(bucket_name: str) -> bool:\n    \"\"\"\n    Validates if a bucket name follows AWS S3 naming conventions.\n    \n    AWS S3 bucket naming rules:\n    - Must be between 3 and 63 characters long\n    - Must contain only lowercase letters, numbers, hyphens, and periods\n    - Must start and end with a letter or number\n    - Cannot contain underscores\n    - Cannot be formatted as an IP address (e.g., 192.168.1.1)\n    \n    Args:\n        bucket_name (str): The S3 bucket name to validate\n        \n    Returns:\n        bool: True if valid, False otherwise\n    \"\"\"\n    # Check if bucket_name is a string\n    if not isinstance(bucket_name, str):\n        return False\n    \n    # Check length (3-63 characters)\n    if len(bucket_name) < 3 or len(bucket_name) > 63:\n        return False\n    \n    # Check for underscores (not allowed)\n    if '_' in bucket_name:\n        return False\n    \n    # Check if it contains only lowercase letters, numbers, hyphens, and periods\n    if not all(c.islower() or c.isdigit() or c in '-.' for c in bucket_name):\n        return False\n    \n    # Check if it starts and ends with a letter or number\n    if not (bucket_name[0].isalnum() and bucket_name[-1].isalnum()):\n        return False\n    \n    # Check if it's formatted as an IP address (not allowed)\n    if all(part.isdigit() for part in bucket_name.split('.')):\n        return False\n    \n    return True\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        (\"my-bucket\", True),                    # Valid\n        (\"my-bucket-123\", True),                # Valid\n        (\"bucket.with.dots\", True),             # Valid\n        (\"a\", False),                           # Too short\n        (\"ab\", False),                          # Too short\n        (\"abc\", True),                          # Minimum valid length\n        (\"a\" * 64, False),                      # Too long\n        (\"a\" * 63, True),                       # Maximum valid length\n        (\"My-Bucket\", False),                   # Contains uppercase\n        (\"my_bucket\", False),                   # Contains underscore\n        (\"my-bucket-\", False),                  # Ends with hyphen\n        (\"-my-bucket\", False),                  # Starts with hyphen\n        (\"my--bucket\", True),                   # Double hyphen is allowed\n        (\"192.168.1.1\", False),                 # IP address format\n        (\"my.bucket.123\", True),                # Valid with dots\n        (\"\", False),                            # Empty string\n        (123, False),                           # Not a string\n        (\"my bucket\", False),                   # Contains space\n        (\"my@bucket\", False),                   # Contains invalid character\n    ]\n    \n    print(\"S3 Bucket Name Validation Tests:\\n\")\n    for bucket_name, expected in test_cases:\n        result = is_valid_s3_bucket_name(bucket_name)\n        status = \"\u2713\" if result == expected else \"\u2717\"\n        print(f\"{status} '{bucket_name}' -> {result} (expected {expected})\")\n```\n\n**Output:**\n```\nS3 Bucket Name Validation Tests:\n\n\u2713 'my-bucket' -> True (expected True)\n\u2713 'my-bucket-123' -> True (expected True)\n\u2713 'bucket.with.dots' -> True (expected True)\n\u2713 'a' -> False (expected False)\n\u2713 'ab' -> False (expected False)\n\u2713 'abc' -> True (expected True)\n\u2713 'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa' -> False (expected False)\n\u2713 'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS S3 bucket name and returns True if it follows AWS naming conventions (lowercase, 3-63 characters, no underscores), False otherwise."
#     },
#     "score": 7,
#     "reasoning": "The solution demonstrates strong understanding of AWS S3 naming conventions and implements most rules correctly. The core validation logic is sound for typical use cases. However, the IP address detection has a logical flaw that could allow invalid bucket names, and the incomplete test output raises concerns about whether all tests actually pass. The code is well-structured and documented, but these edge case issues prevent it from being production-ready without fixes."
#   },
#   {
#     "output": "# AWS IAM Read-Only S3 Bucket Policy\n\nHere's a JSON object that represents an AWS IAM policy for read-only access to a specific S3 bucket:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"ListBucketContents\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketLocation\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket\"\n    },\n    {\n      \"Sid\": \"ReadObjectsInBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket/*\"\n    }\n  ]\n}\n```\n\n## Policy Breakdown\n\n| Component | Purpose |\n|-----------|---------|\n| **Version** | Specifies the policy language version (always use \"2012-10-17\") |\n| **ListBucket** | Allows listing objects in the bucket |\n| **GetBucketLocation** | Allows retrieving bucket region information |\n| **GetObject** | Allows reading/downloading objects from the bucket |\n| **GetObjectVersion** | Allows accessing specific versions of objects |\n| **Resource ARNs** | `arn:aws:s3:::my-data-bucket` for bucket operations and `arn:aws:s3:::my-data-bucket/*` for object operations |\n\nThis policy grants read-only permissions while preventing any write, delete, or administrative operations on the bucket.",
#     "test_case": {
#       "task": "Create a JSON object that represents an AWS IAM policy allowing read-only access to a specific S3 bucket named 'my-data-bucket'."
#     },
#     "score": 8,
#     "reasoning": "The solution provides a functionally correct and well-documented IAM policy that successfully grants read-only S3 access. The core permissions (ListBucket, GetBucketLocation, GetObject) are accurate and properly scoped. However, it could be more refined by removing potentially unnecessary permissions and acknowledging security best practices like conditional restrictions. The explanation adds significant value but could mention least privilege considerations."
#   },
#   {
#     "output": "# AWS EC2 Instance ID Regex Pattern\n\nHere's the regex pattern that matches valid AWS EC2 instance IDs:\n\n```regex\n^i-[0-9a-f]{17}$\n```\n\n## Explanation\n\n| Component | Meaning |\n|-----------|---------|\n| `^` | Start of string |\n| `i-` | Literal \"i-\" prefix (required for EC2 instance IDs) |\n| `[0-9a-f]{17}` | Exactly 17 hexadecimal characters (0-9, a-f) |\n| `$` | End of string |\n\n## Examples\n\n### Valid matches:\n- `i-0a1b2c3d4e5f6g7h8` \u274c (contains 'g', invalid)\n- `i-0a1b2c3d4e5f6a7b8` \u2705\n- `i-1234567890abcdef0` \u2705\n- `i-ffffffffffffffff` \u2705 (only 16 f's - needs 17) \u274c\n\n### Valid examples:\n- `i-0123456789abcdef0` \u2705\n- `i-aaaaaaaaaaaaaaaa0` \u2705\n\n## Implementation Examples\n\n**Python:**\n```python\nimport re\n\npattern = r'^i-[0-9a-f]{17}$'\ninstance_id = \"i-0a1b2c3d4e5f6a7b8\"\n\nif re.match(pattern, instance_id):\n    print(\"Valid EC2 Instance ID\")\nelse:\n    print(\"Invalid EC2 Instance ID\")\n```\n\n**JavaScript:**\n```javascript\nconst pattern = /^i-[0-9a-f]{17}$/;\nconst instanceId = \"i-0a1b2c3d4e5f6a7b8\";\n\nif (pattern.test(instanceId)) {\n    console.log(\"Valid EC2 Instance ID\");\n}\n```\n\n**Case-insensitive version** (if needed):\n```regex\n^i-[0-9a-fA-F]{17}$\n```",
#     "test_case": {
#       "task": "Write a regex pattern that matches valid AWS EC2 instance IDs (format: i- followed by 17 hexadecimal characters)."
#     },
#     "score": 6,
#     "reasoning": "The solution correctly solves the core task with an accurate regex pattern and provides good implementation examples. However, the examples section is significantly flawed with contradictory markings that undermine confidence in the solution. The documentation errors (incorrectly labeled valid/invalid examples) are a notable quality issue that would confuse users. The core pattern itself is sound, but the presentation needs correction."
#   }
# ]

# %%
print(json.dumps(results, indent=2))
